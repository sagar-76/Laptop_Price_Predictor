# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('laptop_data.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
# ets check if there any duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
#I will remove column =Unnamed
# from Ram column i will remove GB and make tht column integer instead of object
# same withMemory column wwill remove GB and make it in to integer
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
# LETS REPLACE GB FROM RAM
df['Ram']=df['Ram'].str.replace('GB', '')
# we use str bcoz our Ram column is string right now thts why

# %%
df['Weight']=df['Weight'].str.replace('kg', '')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
# Ram and weight ase opbjh=ect kets change thenm
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# # Now we gonna perform some EDA
# # for both Univariate and Bivariate

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_1116\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# you can see our datais little bit skewed which is quit obvious
#bcoz laptop uh know comes more in the rnge of 50000 to 1lakh

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df['Company'].value_counts().plot(kind='bar')
# this is univariate  as it is single colum and it is category colum
# so we can plot bar chart
# Out:
# <Axes: xlabel='Company'>

# %%
import matplotlib.pyplot as plt

# %%
#lets check the average price oflaptop from each company
sns.barplot(x=df['Company'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()
# maximumprice of laptop has razor

# %%
# So price varies from which company uh are buying laptop

# %%
df['TypeName'].value_counts().plot(kind='bar')
# we have 6 types of TypeName
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()
# see Notebook is in not that costlu thats why it is selling more and more

# %%
sns.distplot(df['Inches'])# sabse jyada laptop 15.5 inches mai hai
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_1116\1288023253.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])# sabse jyada laptop 15.5 inches mai hai
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'], y=df['Price'])
# see jse jse size bd rha laptop ka price bd rha hai
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %% [markdown]
# # Now see ScreenResolution this is difficult bcox ek standard form m ni diya hai infor
# # har laptop ka alag alag diya hai so

# %%
df['ScreenResolution'].value_counts()
#dkho sbne alag alah diya hai but sabme ek chiz hai
# vo hai uski values=1920*1080
# or 1366*788 like ye numbers

# this its also telling that laptop is touch screen or not

# the its also tlling that IPS pannel hai ya ni
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
# so let  filter the touchscreen oyut
df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1298    1
# 1299    1
# 1300    0
# 1301    0
# 1302    0
# Name: ScreenResolution, Length: 1303, dtype: int64

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# see jyada vo bikte hai jo touch screen
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'], y=df['Price'])
# see jyada mhnge vo hai jo touch screen hai
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
# now we will laptop has IPS or not
df['IPS_pannel']=df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df['IPS_pannel'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS_pannel'>

# %%
sns.barplot(x=df['IPS_pannel'], y=df['Price'])
# Out:
# <Axes: xlabel='IPS_pannel', ylabel='Price'>

# %%
# now we will extract this part 2560*1600
# so x resolutiowill be 2560 and y resolutionwill be 1600
df['ScreenResolution'].str.split('x', expand=True)
# see now we can extract 0 and 1 and we will have resolution
#basically 0 has Ips panel retina display 2560
# and y has 1600
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
newdf=df['ScreenResolution'].str.split('x', expand=True)
#SPLIT ON'X

# %%
df['X_res']=newdf[0]
df['y_res']=newdf[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
# see hmne y_resolution to milgya
# for x we will use regular epres
# this code is to remove all types ofal[ha and only have that resolutio part]
df['X_res'] =df['X_res'].str.replace(',', '').str.findall(r'(\d+\.?\d+)').apply(lambda x : x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
df['X_res']=df['X_res'].astype('int')
df['y_res']=df['y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS_pannel        1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df1=df.select_dtypes(include='number')
df1
# Out:
#       Inches  Ram  Weight        Price  Touchscreen  IPS_pannel  X_res  y_res
# 0       13.3    8    1.37   71378.6832            0           1   2560   1600
# 1       13.3    8    1.34   47895.5232            0           0   1440    900
# 2       15.6    8    1.86   30636.0000            0           0   1920   1080
# 3       15.4   16    1.83  135195.3360            0           1   2880   1800
# 4       13.3    8    1.37   96095.8080            0           1   2560   1600
# ...      ...  ...     ...          ...          ...         ...    ...    ...
# 1298    14.0    4    1.80   33992.6400            1           1   1920   1080
# 1299    13.3   16    1.30   79866.7200            1           1   3200   1800
# 1300    14.0    2    1.50   12201.1200            0           0   1366    768
# 1301    15.6    6    2.19   40705.9200            0           0   1366    768
# 1302    15.6    4    2.20   19660.3200            0           0   1366    768
#
# [1303 rows x 8 columns]

# %%
df1.corr()
# Out:
#                Inches       Ram    Weight     Price  Touchscreen  IPS_pannel  \
# Inches       1.000000  0.237993  0.827631  0.068197    -0.361735   -0.114804
# Ram          0.237993  1.000000  0.383874  0.743007     0.116984    0.206623
# Weight       0.827631  0.383874  1.000000  0.210370    -0.294620    0.016967
# Price        0.068197  0.743007  0.210370  1.000000     0.191226    0.252208
# Touchscreen -0.361735  0.116984 -0.294620  0.191226     1.000000    0.150512
# IPS_pannel  -0.114804  0.206623  0.016967  0.252208     0.150512    1.000000
# X_res       -0.071245  0.433121 -0.032880  0.556529     0.351066    0.281457
# y_res       -0.095404  0.424437 -0.053846  0.552809     0.357930    0.289030
#
#                 X_res     y_res
# Inches      -0.071245 -0.095404
# Ram          0.433121  0.424437
# Weight      -0.032880 -0.053846
# Price        0.556529  0.552809
# Touchscreen  0.351066  0.357930
# IPS_pannel   0.281457  0.289030
# X_res        1.000000  0.994219
# ...

# %%
df1.corr()['Price']
# Inchesnsabse kab releted hai Price se
# Ram, X_res and Y-res are the most important column for price
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS_pannel     0.252208
# X_res          0.556529
# y_res          0.552809
# Name: Price, dtype: float64

# %%
# now we will make new column PPI we will use 3columns Inches, X_res, y_res
# PPI means PIXEL PER INCH
# we use this term PPI in terms of LAPTOP
# which means if PPI is High then Price will be increased
# So we gonna use X_res, y_res, and inches
# formula of ppi is Sqyare root of X_res+sq_root of y_res/Inches
df['PPI']=(((df['X_res']**2)+(df['y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df2=df.select_dtypes(include='number')
df2
# Out:
#       Inches  Ram  Weight        Price  Touchscreen  IPS_pannel  X_res  y_res  \
# 0       13.3    8    1.37   71378.6832            0           1   2560   1600
# 1       13.3    8    1.34   47895.5232            0           0   1440    900
# 2       15.6    8    1.86   30636.0000            0           0   1920   1080
# 3       15.4   16    1.83  135195.3360            0           1   2880   1800
# 4       13.3    8    1.37   96095.8080            0           1   2560   1600
# ...      ...  ...     ...          ...          ...         ...    ...    ...
# 1298    14.0    4    1.80   33992.6400            1           1   1920   1080
# 1299    13.3   16    1.30   79866.7200            1           1   3200   1800
# 1300    14.0    2    1.50   12201.1200            0           0   1366    768
# 1301    15.6    6    2.19   40705.9200            0           0   1366    768
# 1302    15.6    4    2.20   19660.3200            0           0   1366    768
#
#              PPI
# ...

# %%
df2.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS_pannel     0.252208
# X_res          0.556529
# y_res          0.552809
# PPI            0.473487
# Name: Price, dtype: float64

# %%
# Out:
#    Inches  Ram  Weight        Price  Touchscreen  IPS_pannel  X_res  y_res
# 0    13.3    8    1.37   71378.6832            0           1   2560   1600
# 1    13.3    8    1.34   47895.5232            0           0   1440    900
# 2    15.6    8    1.86   30636.0000            0           0   1920   1080
# 3    15.4   16    1.83  135195.3360            0           1   2880   1800
# 4    13.3    8    1.37   96095.8080            0           1   2560   1600

# %%
# so rather than using inches X-res or y_res we will use ppi
# we drop screen reolution
# df.drop(columns=['ScreenResolution', 'Inches', 'X_res', 'y_res'], inplace=True)
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS_pannel  X_res  y_res         PPI
# 0   71378.6832            0           1   2560   1600  226.983005
# ...

# %%
df.drop(columns=['Inches','X_res','y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS_pannel         PPI
# 0           1  226.983005
# ...

# %%
df['Cpu']# now we will preprocess this too
# Out:
# 0                       Intel Core i5 2.3GHz
# 1                       Intel Core i5 1.8GHz
# 2                 Intel Core i5 7200U 2.5GHz
# 3                       Intel Core i7 2.7GHz
# 4                       Intel Core i5 3.1GHz
#                         ...
# 1298              Intel Core i7 6500U 2.5GHz
# 1299              Intel Core i7 6500U 2.5GHz
# 1300    Intel Celeron Dual Core N3050 1.6GHz
# 1301              Intel Core i7 6500U 2.5GHz
# 1302    Intel Celeron Dual Core N3050 1.6GHz
# Name: Cpu, Length: 1303, dtype: object

# %%
df['Cpu'].value_counts().nunique()
# we have 27 types of different processor
# Out:
# 27

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
# right now we have diicded instead of 27 categories we will make 
# 5 categories
#1 will be Intelcore i7
#2 will be Intelcore i5
# 3 will be Intelcore i3
# 4 will be Intel others
# 5 will be AMD

# %%
# how we gona do that we will extract 1 st three words
df['Cpu'].apply(lambda x: x.split()[0:3])
# Out:
# 0            [Intel, Core, i5]
# 1            [Intel, Core, i5]
# 2            [Intel, Core, i5]
# 3            [Intel, Core, i7]
# 4            [Intel, Core, i5]
#                  ...
# 1298         [Intel, Core, i7]
# 1299         [Intel, Core, i7]
# 1300    [Intel, Celeron, Dual]
# 1301         [Intel, Core, i7]
# 1302    [Intel, Celeron, Dual]
# Name: Cpu, Length: 1303, dtype: object

# %%
df['Cpu_Name']=df['Cpu'].apply(lambda x:" ".join( x.split()[0:3]))
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS_pannel         PPI       Cpu_Name
# ...

# %%
# first convert them in to string
def fetch_processor(text):
    if text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu_Brand']=df['Cpu_Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS_pannel         PPI       Cpu_Name      Cpu_Brand
# ...

# %%
df['Cpu_Brand'].value_counts()
# Out:
# Cpu_Brand
# Intel Core i7            527
# Intel Core i5            423
# Other Intel Processor    154
# Intel Core i3            136
# AMD Processor             63
# Name: count, dtype: int64

# %%
df['Cpu_Brand'].value_counts().plot(kind='bar')
# sabse jyada i7 hai and sabs ekam adm
# Out:
# <Axes: xlabel='Cpu_Brand'>

# %%
sns.barplot(x=df['Cpu_Brand'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu', 'Cpu_Name'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS_pannel         PPI  \
# 0  macOS    1.37   71378.6832            0           1  226.983005
# 1  macOS    1.34   47895.5232            0           0  127.677940
# 2  No OS    1.86   30636.0000            0           0  141.211998
# 3  macOS    1.83  135195.3360            0           1  220.534624
# 4  macOS    1.37   96095.8080            0           1  226.983005
#
#        Cpu_Brand
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# 3  Intel Core i7
# ...

# %%
df['Ram'].value_counts().plot(kind='bar')
# sabse jyada 8gb ram vale laptop bikte hai
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()
# sabse jyada mhnge 64 gb Ram vale laptop so they hyae linear relationship

# %%
df['Memory'].value_counts()
# You can see ye bhi kafi diifficult colum hai
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
# so we will divide this in to 4 categories
#1 SSD, #2 HDD, 3Flash Storage, 4 Hybrid
# these all 4 are in Memmory colujmn so dontg get confused

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS_pannel         PPI  \
# 0  macOS    1.37   71378.6832            0           1  226.983005
# 1  macOS    1.34   47895.5232            0           0  127.677940
# 2  No OS    1.86   30636.0000            0           0  141.211998
# 3  macOS    1.83  135195.3360            0           1  220.534624
# 4  macOS    1.37   96095.8080            0           1  226.983005
#
#        Cpu_Brand
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# 3  Intel Core i7
# ...

# %%
# df['SSD']=df['SSD'].str.replace('GB','')
# df['HDD']=df['HDD'].str.replace('GB','')
# df['Flash Storage']=df['Flash Storage'].str.replace('GB','')
# df['Hybrid']=df['Hybrid'].str.replace('GB','')

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS_pannel         PPI  \
# 0  macOS    1.37   71378.6832            0           1  226.983005
# 1  macOS    1.34   47895.5232            0           0  127.677940
# 2  No OS    1.86   30636.0000            0           0  141.211998
# 3  macOS    1.83  135195.3360            0           1  220.534624
# 4  macOS    1.37   96095.8080            0           1  226.983005
#
#        Cpu_Brand
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# 3  Intel Core i7
# ...

# %%
df=df.fillna(0)
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS_pannel         PPI  \
# 0  macOS    1.37   71378.6832            0           1  226.983005
# 1  macOS    1.34   47895.5232            0           0  127.677940
# 2  No OS    1.86   30636.0000            0           0  141.211998
# 3  macOS    1.83  135195.3360            0           1  220.534624
# 4  macOS    1.37   96095.8080            0           1  226.983005
#
#        Cpu_Brand
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# 3  Intel Core i7
# ...

# %%
# df['SSD']=df['SSD'].str.replace('SSD','')
# df['HDD']=df['HDD'].str.replace('HDD','')
# df['Flash Storage']=df['Flash Storage'].str.replace('Flash Storage','')
# df['Hybrid']=df['Hybrid'].str.replace('Hybrid','')

# %%
df=df.fillna(0)
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS_pannel  ...  \
# 0  macOS    1.37   71378.6832            0           1  ...
# 1  macOS    1.34   47895.5232            0           0  ...
# 2  No OS    1.86   30636.0000            0           0  ...
# 3  macOS    1.83  135195.3360            0           1  ...
# 4  macOS    1.37   96095.8080            0           1  ...
#
#                first second Layer1HDD Layer1SSD  Layer1Hybrid  \
# 0            128 SSD      0         0         1             0
# ...

# %%
df.sample(10)
# Out:
#      Company   TypeName  Ram                Memory  \
# 417       HP  Ultrabook    8             256GB SSD
# 937      MSI     Gaming    8  128GB SSD +  1TB HDD
# 1009      HP   Notebook    4             500GB HDD
# 1215    Acer    Netbook    2              32GB SSD
# 643     Asus     Gaming    8               1TB HDD
# 653      MSI     Gaming    8  128GB SSD +  1TB HDD
# 1076  Lenovo   Notebook    4               1TB HDD
# 938     Dell  Ultrabook    8             256GB SSD
# 774       HP  Ultrabook    4             256GB SSD
# 681     Asus   Notebook    4             128GB SSD
#
#                              Gpu       OpSys  Weight      Price  Touchscreen  \
# 417        Intel HD Graphics 520  Windows 10    1.43  79920.000            0
# 937      Nvidia GeForce GTX 1050  Windows 10    2.20  63882.720            0
# 1009       Intel HD Graphics 620  Windows 10    1.64  36443.520            0
# 1215           Intel HD Graphics   Chrome OS    1.30   9270.720            0
# ...

# %%
# # Convert 'Memory' column to string and remove '.0' from the end of each string
# df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)

# # replacing Gb with nothing
# df["Memory"] = df["Memory"].str.replace('GB', '')
# # replacing TB with '000'
# df["Memory"] = df["Memory"].str.replace('TB', '000')
# # string them in new df
# new = df["Memory"].str.split("+", n = 1, expand = True)
# # in memory column khi jaga pr do do memry use hui hai like
# # 126 ssd + 256HDD so hmne slit kra (+) par
# # heree n=1 means sirf ek bar split hona chaiye use jyada ni in a single row
# #expand=True measn it will return a dataframe
# # if uh guve False it will return series

# %%
new
# Out:
#                       0     1
# 0               128 SSD  None
# 1     128 Flash Storage  None
# 2               256 SSD  None
# 3               512 SSD  None
# 4               256 SSD  None
# ...                 ...   ...
# 1298            128 SSD  None
# 1299            512 SSD  None
# 1300   64 Flash Storage  None
# 1301           1000 HDD  None
# 1302            500 HDD  None
#
# [1303 rows x 2 columns]

# %%
df.sample() # lik in this we have 2 memmory in single laptop
# Out:
#      Company   TypeName  Ram   Memory                    Gpu       OpSys  \
# 1065    Dell  Ultrabook    8  256 SSD  Intel HD Graphics 620  Windows 10
#
#       Weight     Price  Touchscreen  IPS_pannel  ...    first second  \
# 1065    1.29  77682.24            0           0  ...  256 SSD      0
#
#      Layer1HDD Layer1SSD  Layer1Hybrid  Layer1Flash_Storage  Layer2HDD  \
# 1065         0         1             0                    0          0
#
#       Layer2SSD  Layer2Hybrid  Layer2Flash_Storage
# 1065          0             0                    0
#
# [1 rows x 22 columns]

# %%
# # now we will divide that mermory column in to 2 parts on which i split it akready
# df['first']=new[0]
# df['first']=df['first'].str.strip()
# # we convert that first in to string 
# # and.strip will removve some character which is not needy for algo
# df['second']=new[1]

# %%
# # Create binary columns indicating the presence of certain terms in the 'first' column
# df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
# df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
# df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
# df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS_pannel  ...  \
# 0  macOS    1.37   71378.6832            0           1  ...
# 1  macOS    1.34   47895.5232            0           0  ...
# 2  No OS    1.86   30636.0000            0           0  ...
# 3  macOS    1.83  135195.3360            0           1  ...
# 4  macOS    1.37   96095.8080            0           1  ...
#
#                first second Layer1HDD Layer1SSD  Layer1Hybrid  \
# 0            128 SSD   None         0         1             0
# ...

# %%
# lets remove the non numeric column from the first column

# df['first'] = df['first'].str.split().str[0]
# df['first'].head()
# Out:
# 0    128
# 1    128
# 2    256
# 3    512
# 4    256
# Name: first, dtype: object

# %%
# same steps for second column but first fille those nul values
# bcoz sabme to do memory hai ni
# df['second'].fillna('0', inplace=True)

# %%
# # Create binary columns indicating the presence of certain terms in the 'second' column
# df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
# df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
# df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
# df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# %%
# # lets replace all non numeric re
# #df['second'] = df['second'].str.split().str[0]
# df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS_pannel  ...  first second  \
# 0  macOS    1.37   71378.6832            0           1  ...    128      0
# 1  macOS    1.34   47895.5232            0           0  ...    128      0
# 2  No OS    1.86   30636.0000            0           0  ...    256      0
# 3  macOS    1.83  135195.3360            0           1  ...    512      0
# 4  macOS    1.37   96095.8080            0           1  ...    256      0
#
# ...

# %%
df.sample(10)
# Out:
#      Company   TypeName  Ram               Memory  \
# 417       HP  Ultrabook    8              256 SSD
# 554       HP   Notebook    8             1000 HDD
# 1199     MSI     Gaming   16  256 SSD +  1000 HDD
# 403     Acer   Notebook    8              256 SSD
# 1296      HP    Netbook    2     32 Flash Storage
# 271     Asus     Gaming   16  256 SSD +  1000 HDD
# 1177  Lenovo     Gaming   16              512 SSD
# 223       HP   Notebook    8             1000 HDD
# 249    Apple  Ultrabook    8              512 SSD
# 1266      HP   Notebook    6          1000 Hybrid
#
#                                Gpu       OpSys  Weight        Price  \
# 417          Intel HD Graphics 520  Windows 10    1.43   79920.0000
# 554           Nvidia GeForce 930MX  Windows 10    2.63   68198.4000
# 1199       Nvidia GeForce GTX 1060  Windows 10    2.43  109165.3920
# 403        Nvidia GeForce GTX 1050       Linux    2.50   46833.1200
# 1296         Intel HD Graphics 400  Windows 10    1.17   11135.5200
# ...

# %%
# # convert first and second in to int bcoz we will a[ply some function
# df["first"] = df["first"].astype(int)
# df["second"] = df["second"].astype(int)

# %%
# df['HDD']=df['first']*df['Layer1HDD']+ df['second']*df['Layer2HDD']
# # yee code kya krega in first we have that amount like[128,265,or something]
# # in Layer1HDD we have 128*0 
# # df['Second']=is that amaound
# # df['layer2HDD'] will have 1 0r 0 so  when we multiply
# # for exam we have 128HDD
# # so it will= 128*1+0*0=128 it will give like this

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS_pannel  ...  second Layer1HDD  \
# 0  macOS    1.37   71378.6832            0           1  ...       0         0
# 1  macOS    1.34   47895.5232            0           0  ...       0         0
# 2  No OS    1.86   30636.0000            0           0  ...       0         0
# 3  macOS    1.83  135195.3360            0           1  ...       0         0
# 4  macOS    1.37   96095.8080            0           1  ...       0         0
#
# ...

# %%
# df['SSD']=df['first']*df['Layer1SSD']+ df['second']*df['Layer2SSD']
# df['Hybrid']=df['first']*df['Layer1Hybrid']+ df['second']*df['Layer2Hybrid']
# df['Flash_Storage']=df['first']*df['Layer1Flash_Storage']+ df['second']*df['Layer2Flash_Storage']

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS_pannel  ...  Layer1Hybrid  \
# 0  macOS    1.37   71378.6832            0           1  ...             0
# 1  macOS    1.34   47895.5232            0           0  ...             0
# 2  No OS    1.86   30636.0000            0           0  ...             0
# 3  macOS    1.83  135195.3360            0           1  ...             0
# 4  macOS    1.37   96095.8080            0           1  ...             0
#
#   Layer1Flash_Storage  Layer2HDD  Layer2SSD  Layer2Hybrid  \
# ...

# %%
import pandas as pd

# Assuming df is already defined and contains the data

# Clean up the 'Memory' column
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')

# Split into two parts if there is a '+' in the string
new = df["Memory"].str.split("+", n=1, expand=True)

# Assign first and second parts to new columns
df["first"] = new[0].str.strip()
df["second"] = new[1].str.strip()  # Strip whitespace if second part exists

# Identify the storage type in each part
df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Safely apply to the second column by checking if it's not None
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if x and "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if x and "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if x and "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if x and "Flash Storage" in x else 0)

# Extract numeric values and remove non-numeric characters
df["first"] = df["first"].str.extract('(\d+)').astype(int)
df["second"] = df["second"].str.extract('(\d+)').fillna(0).astype(int)

# Calculate the storage capacities
df["HDD"] = df["first"] * df["Layer1HDD"] + df["second"] * df["Layer2HDD"]
df["SSD"] = df["first"] * df["Layer1SSD"] + df["second"] * df["Layer2SSD"]
df["Hybrid"] = df["first"] * df["Layer1Hybrid"] + df["second"] * df["Layer2Hybrid"]
df["Flash_Storage"] = df["first"] * df["Layer1Flash_Storage"] + df["second"] * df["Layer2Flash_Storage"]

# Drop unnecessary columns
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
                 'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
                 'Layer2Flash_Storage'], inplace=True)

# Display the result
print(df.head())
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS_pannel         PPI  \
# 0  macOS    1.37   71378.6832            0           1  226.983005
# 1  macOS    1.34   47895.5232            0           0  127.677940
# 2  No OS    1.86   30636.0000            0           0  141.211998
# 3  macOS    1.83  135195.3360            0           1  220.534624
# 4  macOS    1.37   96095.8080            0           1  226.983005
#
#        Cpu_Brand  HDD  SSD  Hybrid  Flash_Storage
# 0  Intel Core i5    0  128       0              0
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS_pannel         PPI  \
# 0  macOS    1.37   71378.6832            0           1  226.983005
# 1  macOS    1.34   47895.5232            0           0  127.677940
# 2  No OS    1.86   30636.0000            0           0  141.211998
# 3  macOS    1.83  135195.3360            0           1  220.534624
# 4  macOS    1.37   96095.8080            0           1  226.983005
#
#        Cpu_Brand  HDD  SSD  Hybrid  Flash_Storage
# 0  Intel Core i5    0  128       0              0
# ...

# %%
df.drop(columns=['Memory'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS_pannel         PPI      Cpu_Brand  HDD  SSD  \
# 0   71378.6832            0           1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0           0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0           0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0           1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0           1  226.983005  Intel Core i5    0  256
#
#    Hybrid  Flash_Storage
# 0       0              0
# ...

# %%
df3=df.select_dtypes(include='number')
df3
# Out:
#       Ram  Weight        Price  Touchscreen  IPS_pannel         PPI   HDD  \
# 0       8    1.37   71378.6832            0           1  226.983005     0
# 1       8    1.34   47895.5232            0           0  127.677940     0
# 2       8    1.86   30636.0000            0           0  141.211998     0
# 3      16    1.83  135195.3360            0           1  220.534624     0
# 4       8    1.37   96095.8080            0           1  226.983005     0
# ...   ...     ...          ...          ...         ...         ...   ...
# 1298    4    1.80   33992.6400            1           1  157.350512     0
# 1299   16    1.30   79866.7200            1           1  276.053530     0
# 1300    2    1.50   12201.1200            0           0  111.935204     0
# 1301    6    2.19   40705.9200            0           0  100.454670  1000
# 1302    4    2.20   19660.3200            0           0  100.454670   500
#
#       SSD  Hybrid  Flash_Storage
# 0     128       0              0
# ...

# %%
df3.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS_pannel       0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
# You can see hybrid and Flash_storage itne related ni hai
df.drop(columns=['Hybrid', 'Flash_Storage'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS_pannel         PPI      Cpu_Brand  HDD  SSD
# 0   71378.6832            0           1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0           0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0           0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0           1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0           1  226.983005  Intel Core i5    0  256

# %%
# Lets see GPU column
df['Gpu'].value_counts()
# again see we have categories
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu'].value_counts().nunique()# 30 categories
# Out:
# 30

# %%
# see Gpu m  we can achive first ther company
# like[Intel, Nvidia, ADM]
# also we can achive [HD Graphics, UHD Graphics]
# in Nvidia[GE Force GTX]
# in ADM[Radeon R5,Radion R7, Mali, ]
# and many more but if uh see data is too small 
# so koifyda ni hai itna sab extract krne ka
# so we will only extract company name [Intel, Nvidia, ADM]

# %%
df['Gpu_Brand']=df['Gpu'].apply(lambda x :x.split()[0])

# %%
df.head() # see we have brand name now
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS_pannel         PPI      Cpu_Brand  HDD  SSD  \
# 0   71378.6832            0           1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0           0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0           0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0           1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0           1  226.983005  Intel Core i5    0  256
#
#   Gpu_Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# ...

# %%
df['Gpu_Brand'].value_counts()
# se we have ARM jiski 1 laptop so we gona delete that row jisme bhi ARM hai
# Out:
# Gpu_Brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df[df['Gpu_Brand']=='ARM']
# Out:
#       Company            TypeName  Ram                Gpu      OpSys  Weight  \
# 1191  Samsung  2 in 1 Convertible    4  ARM Mali T860 MP4  Chrome OS    1.15
#
#          Price  Touchscreen  IPS_pannel       PPI      Cpu_Brand  HDD  SSD  \
# 1191  35111.52            1           1  234.5074  AMD Processor    0    0
#
#      Gpu_Brand
# 1191       ARM

# %%
df=df[df['Gpu_Brand']!='ARM']
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS_pannel         PPI      Cpu_Brand  HDD  SSD  \
# 0   71378.6832            0           1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0           0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0           0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0           1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0           1  226.983005  Intel Core i5    0  256
#
#   Gpu_Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# ...

# %%
df['Gpu_Brand'].value_counts()
# See now we have 3 categories
# Out:
# Gpu_Brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu_Brand'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()
# sabse jyada mhng Nvidia ka graphic card  hai

# %%
df.drop(columns=['Gpu'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0
#
#    IPS_pannel         PPI      Cpu_Brand  HDD  SSD Gpu_Brand
# 0           1  226.983005  Intel Core i5    0  128     Intel
# 1           0  127.677940  Intel Core i5    0    0     Intel
# 2           0  141.211998  Intel Core i5    0  256     Intel
# 3           1  220.534624  Intel Core i7    0  512       AMD
# 4           1  226.983005  Intel Core i5    0  256     Intel

# %%
# now let see another colum
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
# see we have different diferent categories
# so to work with lot of categories  is not so god we will 
# make 3 categories 1=Windows which will take all Windows
# 2 mac which will take os
# 3 will be names as other which will include all other

# %%
sns.barplot(x=df['OpSys'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()
# see main are windows and mac jiske price jyadac hai
# or baki sab ke similar hi hai so 
# we put them in to other categories

# %%
def cate_os(inp):
    if inp=='Windows 10' or inp=='Windows 7' or inp=='Windows 10 S':
        return 'Windows'
    elif inp=='macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['OS']=df['OpSys'].apply(cate_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0
#
#    IPS_pannel         PPI      Cpu_Brand  HDD  SSD Gpu_Brand  \
# 0           1  226.983005  Intel Core i5    0  128     Intel
# 1           0  127.677940  Intel Core i5    0    0     Intel
# 2           0  141.211998  Intel Core i5    0  256     Intel
# 3           1  220.534624  Intel Core i7    0  512       AMD
# 4           1  226.983005  Intel Core i5    0  256     Intel
#
#                    OS
# 0                 Mac
# 1                 Mac
# 2  Others/No OS/Linux
# 3                 Mac
# 4                 Mac

# %%
df['OS'].value_counts()
# Out:
# OS
# Windows               1125
# Others/No OS/Linux     156
# Mac                     21
# Name: count, dtype: int64

# %%
df.drop(columns=['OpSys'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS_pannel  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0           1
# 1   Apple  Ultrabook    8    1.34   47895.5232            0           0
# 2      HP   Notebook    8    1.86   30636.0000            0           0
# 3   Apple  Ultrabook   16    1.83  135195.3360            0           1
# 4   Apple  Ultrabook    8    1.37   96095.8080            0           1
#
#           PPI      Cpu_Brand  HDD  SSD Gpu_Brand                  OS
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
sns.barplot(x=df['OS'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df['Weight'], y=df['Price'])
# very weekly linear realtion ship they had
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
# we cam cjheck with correlation
df3.corr()['Price']
# see its only0.21 so its okay
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS_pannel       0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
sns.heatmap(df3.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.distplot(df['Price'])
# see our target column is skweed so we need to normalize it
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_1116\3238327054.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# how we gonna do that
# we can apply Log
sns.distplot(np.log(df['Price']))
# see now its very close to normal distribution
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_1116\904103781.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS_pannel  \
# 0      Apple           Ultrabook    8    1.37            0           1
# 1      Apple           Ultrabook    8    1.34            0           0
# 2         HP            Notebook    8    1.86            0           0
# 3      Apple           Ultrabook   16    1.83            0           1
# 4      Apple           Ultrabook    8    1.37            0           1
# ...      ...                 ...  ...     ...          ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1           1
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1           1
# 1300  Lenovo            Notebook    2    1.50            0           0
# 1301      HP            Notebook    6    2.19            0           0
# 1302    Asus            Notebook    4    2.20            0           0
#
#              PPI              Cpu_Brand   HDD  SSD Gpu_Brand  \
# ...

# %%
y# see prices kam hogye abhi for normalization
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15, random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  IPS_pannel  \
# 183   Toshiba            Notebook    8    2.00            0           0
# 1141      MSI              Gaming    8    2.40            0           0
# 1049     Asus             Netbook    4    1.20            0           0
# 1020     Dell  2 in 1 Convertible    4    2.08            1           1
# 878      Dell            Notebook    4    2.18            0           0
# ...       ...                 ...  ...     ...          ...         ...
# 466      Acer            Notebook    4    2.20            0           0
# 299      Asus           Ultrabook   16    1.63            0           0
# 493      Acer            Notebook    8    2.20            0           0
# 527    Lenovo            Notebook    8    2.20            0           0
# 1193    Apple           Ultrabook    8    0.92            0           1
#
#              PPI              Cpu_Brand   HDD  SSD Gpu_Brand  \
# ...

# %%
# see lets apply label encoder for the categorical columns
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, mean_absolute_error

# %%
# !pip install xgboost

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# # Linear regression

# %%
# we will create column transformer
# step1 = ColumnTransformer(transformers=[
#     ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
# ],remainder='passthrough')
# # remainder='passthrough is warning that only category column m hi change ho
# # [0,1,7,8,10,11]' arr thos column indexes jo category  columns hai
# #'co_tnf is name for that column transformer

# # step2
# step2 = LinearRegression()

# pipe = Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])

# pipe.fit(X_train,y_train)

# y_pred = pipe.predict(X_test)

# print('R2 score',r2_score(y_test,y_pred))
# print('MAE',mean_absolute_error(y_test,y_pred))
# see our r2 score is 0.80


# ColumnTransformer to handle categorical features
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8073277448418701
# MAE 0.21017827976428766
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8073277448418701
# MAE 0.21017827976428766
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8127331031311809
# MAE 0.20926802242582962
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # Lasso Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8071853945317103
# MAE 0.21114361613472568
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8027675291937718
# MAE 0.193456293739003

# %% [markdown]
# # Decision tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8353037448573425
# MAE 0.18591845748884864
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8083180902289917
# MAE 0.2023905942719158

# %% [markdown]
# # Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8873402378382488
# MAE 0.15860130110457718

# %%
import numpy as np

query = np.array(['Apple', 'Ultrabook', 2, 10.00, 1, 1, 226.983005, 'Intel Core i5', 128, 128, 'AMD', 'Mac'])
query = query.reshape(1, -1)  # Reshape to 2D array

predicted_price = pipe.predict(query)
print("Predicted price:", predicted_price)
# Out:
# Predicted price: [10.57001419]
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
import numpy as np

query = np.array(['Apple', 'Ultrabook', 2, 10.00, 1, 1, 226.983005, 'Intel Core i5', 128, 128, 'AMD', 'Mac'])
query = query.reshape(1, -1)  # Reshape to 2D array

predicted_price = pipe.predict(query)
print("Predicted price:", predicted_price)
# Out:
# Predicted price: [10.57001419]
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Extra Tress

# %%
# step1 = ColumnTransformer(transformers=[
#     ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
# ],remainder='passthrough')

# step2 = ExtraTreesRegressor(n_estimators=100,
#                               random_state=3,
#                               max_samples=0.5,
#                               max_features=0.75,
#                               max_depth=15)

# pipe = Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])

# pipe.fit(X_train,y_train)

# y_pred = pipe.predict(X_test)

# print('R2 score',r2_score(y_test,y_pred))
# print('MAE',mean_absolute_error(y_test,y_pred))

# %% [markdown]
# # Ada Boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7974236147674161
# MAE 0.22996515145589444
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # Gradient Boot

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8818603073801446
# MAE 0.15960813474247054

# %% [markdown]
# # XG Boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8771404806375557
# MAE 0.16262936288951352
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor


step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first'), [0, 1, 7, 10, 11])
], remainder='passthrough')

rf = RandomForestRegressor(n_estimators=350, random_state=3, max_features=0.75, max_depth=15)
#gbdt = GradientBoostingRegressor(n_estimators=100, max_features=0.5)
xgb = XGBRegressor(n_estimators=25, learning_rate=0.3, max_depth=5)
#et = ExtraTreesRegressor(n_estimators=100, random_state=3, max_features=0.75, max_depth=10)

step2 = VotingRegressor([('rf', rf), ('xgb', xgb)], weights=[8,1])

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

print('R2 score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))
# Out:
# D:\Users\harsh\anaconda3\envs\tensarflow\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8888845643981264
# MAE 0.15623940939042216

# %%
import pickle

# %%
pickle.dump(df, open('df_final.pkl', 'wb'))

# basically pip jo hmne model bnaya hai

# %%
pickle.dump(pipe, open('pipe_final1.pkl', 'wb'))

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS_pannel  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0           1
# 1   Apple  Ultrabook    8    1.34   47895.5232            0           0
# 2      HP   Notebook    8    1.86   30636.0000            0           0
# 3   Apple  Ultrabook   16    1.83  135195.3360            0           1
# 4   Apple  Ultrabook    8    1.37   96095.8080            0           1
#
#           PPI      Cpu_Brand  HDD  SSD Gpu_Brand                  OS
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   object
#  1   TypeName     1302 non-null   object
#  2   Ram          1302 non-null   int32
#  3   Weight       1302 non-null   float32
#  4   Price        1302 non-null   float64
#  5   Touchscreen  1302 non-null   int64
#  6   IPS_pannel   1302 non-null   int64
#  7   PPI          1302 non-null   float64
#  8   Cpu_Brand    1302 non-null   object
#  9   HDD          1302 non-null   int64
#  10  SSD          1302 non-null   int64
#  11  Gpu_Brand    1302 non-null   object
#  12  OS           1302 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(4), object(5)
# memory usage: 132.2+ KB

# %%
type(pipe)
# Out:
# sklearn.pipeline.Pipeline
